# %% [markdown]
# ###Matplotlib Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/car_price.csv')
df.sample(5)
# Out:
#      Unnamed: 0  car_ID  symboling               CarName fueltype aspiration  \
# 4             4       5          2            audi 100ls      gas        std
# 194         194     195         -2       volvo 145e (sw)      gas        std
# 80           80      81          3  mitsubishi mirage g4      gas      turbo
# 79           79      80          1         mitsubishi g4      gas      turbo
# 113         113     114          0           peugeot 504      gas        std
#
#     doornumber    carbody drivewheel  wheelbase  ...  enginesize  fuelsystem  \
# 4         four      sedan        4wd       99.4  ...         136        mpfi
# 194       four      sedan        rwd      104.3  ...         141        mpfi
# 80         two  hatchback        fwd       96.3  ...         110        spdi
# 79         two  hatchback        fwd       93.0  ...          98        spdi
# 113       four      wagon        rwd      114.2  ...         120        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 4         3.19    3.40              8.0        115     5500      18
# 194       3.78    3.15              9.5        114     5400      23
# 80        3.17    3.46              7.5        116     5500      23
# 79        3.03    3.39              7.6        102     5500      24
# 113       3.46    2.19              8.4         95     5000      19
#
#      highwaympg    price
# 4            22  17450.0
# 194          28  12940.0
# 80           30   9959.0
# 79           30   7689.0
# 113          24  16695.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_ID', 'symboling', 'CarName', 'fueltype',
#        'aspiration', 'doornumber', 'carbody', 'drivewheel', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.sample(5)
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 151     152          1    toyota corona      gas        std        two
# 15       16          0           bmw x4      gas        std       four
# 96       97          1     nissan latio      gas        std       four
# 26       27          1  dodge colt (sw)      gas        std       four
# 70       71         -1    buick skyhawk   diesel      turbo       four
#
#        carbody drivewheel  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 151  hatchback        fwd       95.7      158.7  ...          92        2bbl
# 15       sedan        rwd      103.5      189.0  ...         209        mpfi
# 96       sedan        fwd       94.5      165.3  ...          97        2bbl
# 26       sedan        fwd       93.7      157.3  ...          90        2bbl
# 70       sedan        rwd      115.6      202.6  ...         183         idi
#
#      boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# 151       3.05   3.03              9.0          62    4800       31
# 15        3.62   3.39              8.0         182    5400       16
# 96        3.15   3.29              9.4          69    5200       31
# 26        2.97   3.23              9.4          68    5500       31
# 70        3.58   3.64             21.5         123    4350       22
#
#      highwaympg    price
# 151          38   6338.0
# 15           22  30760.0
# 96           37   7499.0
# 26           38   7609.0
# 70           25  31600.0
#
# [5 rows x 25 columns]

# %%
df.set_index('car_ID', inplace=True)
df.sample(5)
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 36              0           honda accord lx      gas        std       four
# 43              1        honda civic (auto)      gas        std        two
# 127             3         porcshce panamera      gas        std        two
# 172             2            toyota corolla      gas        std        two
# 155             0  toyota corolla 1600 (sw)      gas        std       four
#
#           carbody drivewheel  wheelbase  carlength  carwidth  ...  enginesize  \
# car_ID                                                        ...
# 36          sedan        fwd       96.5      163.4      64.0  ...          92
# 43          sedan        fwd       96.5      169.1      66.0  ...         110
# 127       hardtop        rwd       89.5      168.9      65.0  ...         194
# 172     hatchback        rwd       98.4      176.2      65.6  ...         146
# 155         wagon        4wd       95.7      169.7      63.6  ...          92
#
#         fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  \
# car_ID
# 36            1bbl      2.91   3.41               9.2         76     6000
# 43            2bbl      3.15   3.58               9.1        100     5500
# 127           mpfi      3.74   2.90               9.5        207     5900
# 172           mpfi      3.62   3.50               9.3        116     4800
# 155           2bbl      3.05   3.03               9.0         62     4800
#
#         citympg  highwaympg    price
# car_ID
# 36           30          34   7295.0
# 43           25          31  10345.0
# 127          17          25  32528.0
# 172          24          30  11549.0
# 155          27          32   7898.0
#
# [5 rows x 24 columns]

# %%
df.sort_index(inplace=True)
df.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel  wheelbase  carlength  carwidth  ...  \
# car_ID                                                          ...
# 1       convertible        rwd       88.6      168.8      64.1  ...
# 2       convertible        rwd       88.6      168.8      64.1  ...
# 3         hatchback        rwd       94.5      171.2      65.5  ...
# 4             sedan        fwd       99.8      176.6      66.2  ...
# 5             sedan        4wd       99.4      176.6      66.4  ...
#
#         enginesize  fuelsystem boreratio stroke  compressionratio horsepower  \
# car_ID
# 1              130        mpfi      3.47   2.68               9.0        111
# 2              130        mpfi      3.47   2.68               9.0        111
# 3              152        mpfi      2.68   3.47               9.0        154
# 4              109        mpfi      3.19   3.40              10.0        102
# 5              136        mpfi      3.19   3.40               8.0        115
#
#         peakrpm  citympg  highwaympg    price
# car_ID
# 1          5000       21          27  13495.0
# 2          5000       21          27  16500.0
# 3          5000       19          26  16500.0
# 4          5500       24          30  13950.0
# 5          5500       18          22  17450.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ###Numerical Variables

# %%
df[['enginesize', 'horsepower']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 1 to 205
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   enginesize  205 non-null    int64
#  1   horsepower  205 non-null    int64
# dtypes: int64(2)
# memory usage: 4.8 KB

# %% [markdown]
# ###Scatter Plot

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])
plt.show()

# %%
plt.scatter(x = df['enginesize'], y = df['horsepower'])
plt.title('Scatter plot of horsepower of car versus engine size')
# Out:
# Text(0.5, 1.0, 'Scatter plot of horsepower of car versus engine size')

# %%
plt.scatter(x=df['enginesize'], y=df['horsepower'])
plt.title('Scatter plot of horsepower of car versus engine size')
plt.xlabel('size of engine')
plt.ylabel('horsepower')
plt.show()

# %%
plt.scatter(x=df['citympg'], y=df['horsepower'], s=10, marker='^')
plt.title('Scatter plot of horsepower of car versus city mileage')
plt.xlabel('city mileage')
plt.ylabel('horsepower')
plt.show()

# %%
plt.scatter(x=df['citympg'], y=df['horsepower'], s=50, marker='^', alpha=0.5, c = 'r')
plt.title('Scatter plot of horsepower of car versus city mileage')
plt.xlabel('city mileage')
plt.ylabel('horsepower')
plt.show()

# %% [markdown]
# ###Line Chart

# %%
df_ap = pd.read_csv('/content/sample_data/AirPassengers.csv')
df_ap.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
df_ap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
plt.plot(df_ap['Month'],df_ap['Passengers'])
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24))
plt.show()

# %%
plt.plot(df_ap['Month'],df_ap['Passengers'],marker='o')
plt.title('Line plot of monthly number of passengers in the airline')
plt.xlabel('Month')
plt.ylabel('Passengers')
plt.xticks(range(23, 144, 24))
plt.show()

# %% [markdown]
# ###Histogram

# %%
plt.hist(df['price'], bins=5)
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars');

# %%
two_door_df = df[df['doornumber'] == 'two']
four_door_df = df[df['doornumber'] == 'four']

# %%
plt.hist(two_door_df['price'])
plt.hist(four_door_df['price'])
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors');

# %%
plt.hist(two_door_df['price'], label='Two')
plt.hist(four_door_df['price'], label='Four')
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors')
plt.legend();

# %%
plt.hist([two_door_df['price'], four_door_df['price']], alpha=0.5,label=['two door', 'four door'], stacked=True)
plt.xlabel('price')
plt.ylabel('number of cars')
plt.title('Distribution of prices of cars based on number of doors')
plt.legend();

# %% [markdown]
# ###Subplots

# %%
fig, ax = plt.subplots()

# %%
fig, axs = plt.subplots(1, 2, figsize = (8,4))
axs[0].hist(two_door_df['price'], bins=20, color='blue')
axs[0].set_title('Histogram of prices of two door cars')

axs[0].set_xlabel('price')
axs[0].set_ylabel('frequency')
axs[0].tick_params(axis='x', rotation=45)

axs[1].hist(four_door_df['price'], bins = 20, color = 'green')
axs[1].set_title("Histograms of prices of four door cars")

axs[1].set_xlabel('price')
axs[1].set_ylabel('frequency')
axs[1].tick_params(axis='x', rotation=45)

plt.suptitle('Histograms of prices of two door and four door cars')
plt.tight_layout();

# %%
df['doornumber'].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
doornumber_value_counts = df['doornumber'].value_counts()

# %% [markdown]
# ###Piechart

# %%
plt.pie(doornumber_value_counts)
plt.title('Pie chart of distribution of cars based on number of doors')
plt.show()

# %%
plt.pie(doornumber_value_counts.values, labels=doornumber_value_counts.index)
plt.title('Pie chart of distribution of cars based on number of doors')
plt.show()

# %%
pie_labels = [doornumber_value_counts.index[0] + ' ' + str(doornumber_value_counts.iloc[0]),
              doornumber_value_counts.index[1] + ' ' + str(doornumber_value_counts.iloc[1])]
pie_labels
# Out:
# ['four 115', 'two 90']

# %%
plt.pie(doornumber_value_counts.values, labels=pie_labels)
plt.title('Pie chart of distribution of cars based on number of doors');

# %% [markdown]
# ###Count Plot

# %%
carbody_value_counts = df['carbody'].value_counts()
carbody_value_counts
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar(carbody_value_counts.index, carbody_value_counts.values) #
ax.set_xlabel('Types of Cars based on car body')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car body');

# %%
df['cylindernumber'].value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
cylindernumber_value_counts = df['cylindernumber'].value_counts()
cylindernumber_value_counts
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
ax.bar(cylindernumber_value_counts.index, cylindernumber_value_counts.values)
ax.set_xlabel('Types of cars based on number of cylinders')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car based on number of cylinders');

# %%
fig, ax = plt.subplots()
ax.bar(cylindernumber_value_counts.index, cylindernumber_value_counts.values)
ax.set_xlabel('Types of cars based on number of cylinders')
ax.set_ylabel('Count')
ax.set_title('Count plot of type of car based on number of cylinders')
ax.yaxis.grid();

# %% [markdown]
# ###Bar Graphs

# %%
average_prices = df.groupby('carbody')['price'].mean()
average_prices
# Out:
# carbody
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10376.652386
# sedan          14344.270833
# wagon          12371.960000
# Name: price, dtype: float64

# %%
plt.bar(average_prices.index, average_prices.values)
plt.title('Average price of different types of cars based on car body')
plt.xlabel('carbody')
plt.ylabel('price')
plt.grid(axis='y');

# %%
average_prices_sorted = average_prices.sort_values()

# %%
plt.bar(average_prices_sorted.index, average_prices_sorted.values)
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='y');

# %%
average_prices_sorted = average_prices.sort_index()

# %%
plt.bar(average_prices_sorted.index, average_prices_sorted.values)
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='y');

# %%
plt.barh(average_prices_sorted.index, average_prices_sorted.values) # Horizontal bar graph of average prices
plt.title('Average Price of Different Types of Cars based on Car Body')
plt.xlabel('Car Body')
plt.ylabel('Price')
plt.xticks(rotation = 45)
plt.grid(axis='x');

# %%
doornumber_carbody_crosstable = pd.crosstab(df['doornumber'], df['carbody'])
doornumber_carbody_crosstable
# Out:
# carbody     convertible  hardtop  hatchback  sedan  wagon
# doornumber
# four                  0        0         10     80     25
# two                   6        8         60     16      0

# %%
carbody_categories = doornumber_carbody_crosstable.columns
carbody_categories
# Out:
# Index(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'], dtype='object', name='carbody')

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'])
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'])
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'], alpha=0.5)
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'], alpha=0.5)
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['four'], width=0.5)
bar1 = ax.bar(np.arange(len(carbody_categories)), doornumber_carbody_crosstable.loc['two'],width=0.5)
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body');

# %%
fig, ax = plt.subplots()
bar1 = ax.bar(np.arange(len(carbody_categories))-0.2, doornumber_carbody_crosstable.loc['four'], width=0.4,label='four')
bar1 = ax.bar(np.arange(len(carbody_categories))+0.2, doornumber_carbody_crosstable.loc['two'], width=0.4,label='two')
ax.set_xlabel('Index of Categories')
ax.set_ylabel('Count')
ax.set_title('Distribution of number of cars over number of doors and type of car body')
ax.legend();
